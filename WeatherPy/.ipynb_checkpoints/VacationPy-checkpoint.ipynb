# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from config import google_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df = pd.read_csv("../Output/cities.csv")
city_df.head(100)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Truro  50.2653   -5.0544      7.22        93           0
# 1       Launceston -41.4500  147.1667     16.67        58           5
# 2   Vadul lui Vodă  47.0917   29.0756      3.00        93          90
# 3          Bragado -35.1191  -60.4897     17.78        91          80
# 4         Dupnitsa  42.2667   23.1167      4.44        74         100
# ..             ...      ...       ...       ...       ...         ...
# 95         Opochka  56.7105   28.6617      0.79        96         100
# 96           Aalst  50.9433    4.0735      6.67        89         100
# 97         Harburg  53.4667    9.9833      3.33        81          20
# 98        Waukesha  43.0333  -88.3001      1.11        86          90
# 99       Americana -22.7392  -47.3314     20.00        94           0
#
#     Wind speed Country        Date
# 0         1.03      GB  1615970766
# 1         5.14      AU  1615970766
# 2         6.17      MD  1615970767
# 3         2.24      AR  1615970768
# 4         0.45      BG  1615970768
# ..         ...     ...         ...
# 95        3.80      RU  1615970791
# 96        1.79      BE  1615970791
# 97        2.57      DE  1615970791
# 98        0.39      US  1615970791
# 99        3.09      BR  1615970791
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=google_key)

# %%
# Store latitude and longitude in locations
locations = city_df[["Lat", "Lng"]]

# Fill NaN values and convert to float
rating = city_df["Humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Setup my fav weather, and create a new DataFrame
max_temp = 30
max_wind = 10
cloud = 0
humidity = 50
#No Null rows as I have cleaned datafram whilst creating it.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Store into variable named hotel_df
hotel_df = city_df.loc[(city_df["Max Temp"] <= max_temp) &
                           (city_df["Wind speed"] <= max_wind) &
                           (city_df["Cloudiness"] == cloud) &
                           (city_df["Humidity"] <= humidity), :].copy()

hotel_df.head(100)

#Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"]=""
hotel_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind speed  \
# 23      Kavajë  41.1856   19.5569      9.00        46           0        1.03
# 24   Beersheba  31.2518   34.7913     18.89        50           0        1.34
# 28       Heihe  50.2441  127.4902      0.00        32           0        5.00
# 89     Sysert'  56.4953   60.8192      1.00        32           0        7.00
# 108   Plumtree -20.4833   27.8167     26.89        29           0        3.86
#
#     Country        Date Hotel Name
# 23       AL  1615970773
# 24       IL  1615970773
# 28       CN  1615970774
# 89       RU  1615970789
# 108      ZW  1615970795

# %%
# geocoordinates
#target_coordinates = "43.6187102, -116.2146068"
#target_search = "Chinese"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {"radius": target_radius,
    "type": target_type,
    "key": google_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params["location"]= "43.6187102, -116.2146068"
# run a request using our params dictionary
response = requests.get(base_url, params=params)
response_json=response.json()
pprint(response_json)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwKuoGXuztjF6dJyWPb_LSpsGb1j4A8qVEpmlk_OpnSu50_9I7p37gyPgqrPXh0Zlrbfr8F5vDvVFv_LLV8Qzbvw96pJCJHDOU-T_JC88h0oNFe7JztkzVcLpddqLH_O4lxBsBfhLq157f2uOwILPc1aIuva0KDkRDKLNMLwwqTJXugDyQ4pTPchscF7QrC-fXtrH9py5Z_WteuGqbCBZ9D0hFgdJ3B3TtSKlEhN_eYsMJSsQ38MLGrW2l8_WQiCk-c9-JVhmfETafq-jWJpkhBaTIauxgVupcNAZf_hnUt-nAPT1RdhrZpCqqkpUPTJgnSyeDOaGOKFKo-cokDJ-Yta243MceIUrePf4w2ehcorDXthQvO_vaNO1ZLlHZjMaVxtqIk-UYuxG4lJOu1FsNwdU3M0PdSsvCcj6eYTIQ0A-FlpMybL1w',
#  'results': [{'geometry': {'location': {'lat': 43.6150186, 'lng': -116.2023137},
#                            'viewport': {'northeast': {'lat': 43.68989506922873,
#                                                       'lng': -116.1019090625201},
#                                         'southwest': {'lat': 43.51171697252382,
#                                                       'lng': -116.3658869109073}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Boise',
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114395682869662378351">Harish '
#                                                 'Mukundan</a>'],
#                           'photo_reference': 'ATtYBwJUV_4ecxfHdbYWAiHDtX1WUKCyPnn-9YqFbjZwqrjGsDegaXS3_XQ0KEyte4dFPQnzwsqbYXvM4RvUwXllmLSF64taXvEIKfp4aR2yCr6BgPx7R08HDLbQawxpwVD-ZXrMVKxlqqZy2sSjjC-TLMBy_usNgxwpNERQDeTviLAYlZQ_',
#                           'width': 3309}],
#               'place_id': 'ChIJnbRH6XLxrlQRm51nNpuYW5o',
#               'reference': 'ChIJnbRH6XLxrlQRm51nNpuYW5o',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.61555, 'lng': -116.20647},
#                            'viewport': {'northeast': {'lat': 43.6170299802915,
#                                                       'lng': -116.2051330697085},
#                                         'southwest': {'lat': 43.6143320197085,
#                                                       'lng': -116.2078310302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Hotel 43',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2697,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113245403196783401370">Hotel '
#                                                 '43</a>'],
#                           'photo_reference': 'ATtYBwJfYZknulFFZZH7YhiTbF3uZm0wEUInEAb3rNyb6cEeP_NeZTV82e2bQTqd1iEdodt3-DRz2J-XtizFuBgTR1j4r4k99eSqPPh_gV3msEoAPh_EhNHD_E09aMPDBwxU0rmsAWWZgNGjh-XBI2oY8HNu3cgww7JxIVJVhX5h6pQfTwYN',
#                           'width': 4046}],
#               'place_id': 'ChIJNQnEpeX4rlQReKnm_VeFU_0',
#               'plus_code': {'compound_code': 'JQ8V+6C Boise, ID, USA',
#                             'global_code': '85M5JQ8V+6C'},
#               'rating': 4.4,
#               'reference': 'ChIJNQnEpeX4rlQReKnm_VeFU_0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 448,
#               'vicinity': '981 West Grove Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.620326, 'lng': -116.228675},
#                            'viewport': {'northeast': {'lat': 43.62178798029149,
#                                                       'lng': -116.2271306197085},
#                                         'southwest': {'lat': 43.61909001970849,
#                                                       'lng': -116.2298285802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Cottonwood Suites Boise Riverside Downtown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 5992,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102135787386814880373">Cottonwood '
#                                                 'Suites Boise Riverside '
#                                                 'Downtown</a>'],
#                           'photo_reference': 'ATtYBwJrAdedn9jdVKzOgpRTg5HOuyyW0IpfqYDS1hn2bBArRAyBlarA_8I1Hm8hoJgF8lpu9HU5ZZ2tQ7D4tpNcmQy8foOC5rBVwtLQjCZDPx4uiT8B_mXHriLe6qbwGhV-Q4YauAMtwycqtRug0dFQvWOIA7S1h_p8p2Ye_23vbEed0_13',
#                           'width': 3995}],
#               'place_id': 'ChIJvQ54m8D4rlQR9mpRt7fiQE8',
#               'plus_code': {'compound_code': 'JQCC+4G Boise, ID, USA',
#                             'global_code': '85M5JQCC+4G'},
#               'rating': 3.5,
#               'reference': 'ChIJvQ54m8D4rlQR9mpRt7fiQE8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1078,
#               'vicinity': '3031 West Main Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6123321, 'lng': -116.2055216},
#                            'viewport': {'northeast': {'lat': 43.6136269802915,
#                                                       'lng': -116.2040009197085},
#                                         'southwest': {'lat': 43.61092901970851,
#                                                       'lng': -116.2066988802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Hampton Inn & Suites Boise-Downtown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3744,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114551667716962215520">Hampton '
#                                                 'Inn &amp; Suites '
#                                                 'Boise-Downtown</a>'],
#                           'photo_reference': 'ATtYBwLLhJLGHihg3TnSGOZg_nlwTKCLYzjWFM7ppsYrWOwWKGFEsoVB60FCvCtvsMAECrSWUh90xFXV3mHSTaLRyizfS1_iITzcqcav9G31JYtsnlqS2ONHTianrQWmRtcDxR1PlZ_tpHZPIoDr6c44buCAbXbVpMoRxBcu43Q1HpC79c05',
#                           'width': 5242}],
#               'place_id': 'ChIJkf0tnvr4rlQRjL-FWTWCnUg',
#               'plus_code': {'compound_code': 'JQ6V+WQ Boise, ID, USA',
#                             'global_code': '85M5JQ6V+WQ'},
#               'rating': 4.5,
#               'reference': 'ChIJkf0tnvr4rlQRjL-FWTWCnUg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 852,
#               'vicinity': '495 South Capitol Boulevard, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6042232, 'lng': -116.2137018},
#                            'viewport': {'northeast': {'lat': 43.6056676302915,
#                                                       'lng': -116.2123781697085},
#                                         'southwest': {'lat': 43.60296966970851,
#                                                       'lng': -116.2150761302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'TownePlace Suites by Marriott Boise Downtown/University',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106830035009248980494">TownePlace '
#                                                 'Suites by Marriott Boise '
#                                                 'Downtown/University</a>'],
#                           'photo_reference': 'ATtYBwIR-x09XNdMMgiG-zN5cKUqBC9JUlotxxRJoTS5Z1VlkwDeI-IS3FxSvsc2E_6PARyJ94M9n5IP0B2mjrYbVstAsnC38OWMQxoGenKN0kwMBOBI5_d0rO9puJ-84VDq4zzH1PpgnZfN7PBXXuK4wb2OuAgWl3_RfF7wvYGTv5ph_0_d',
#                           'width': 3000}],
#               'place_id': 'ChIJK8VPLIv4rlQRBRtqqcDjKG4',
#               'plus_code': {'compound_code': 'JQ3P+MG Boise, ID, USA',
#                             'global_code': '85M5JQ3P+MG'},
#               'rating': 4.3,
#               'reference': 'ChIJK8VPLIv4rlQRBRtqqcDjKG4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 381,
#               'vicinity': '1455 South Capitol Boulevard, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6211777, 'lng': -116.2164764},
#                            'viewport': {'northeast': {'lat': 43.6224325302915,
#                                                       'lng': -116.2133767},
#                                         'southwest': {'lat': 43.6197345697085,
#                                                       'lng': -116.2181655}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Red Lion Hotel Boise Downtowner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105685292242469997048">Red '
#                                                 'Lion Hotel Boise '
#                                                 'Downtowner</a>'],
#                           'photo_reference': 'ATtYBwLEzRBOJzwWktiLPjecnEItwOOTUMzsXUJo5gztZ_hHwKyVaQOzIAHQNAXKKcVMwt_zEJYfwBC_h1XYHpcioaKodNEzdKWGd5HJQbuBAqxCg7yT3Ar7qZxJ4pVb6iz9gJvvJF-9eVZiuUYilWDRjfGKLUGXS4DBBPN7ARRczChCiRFy',
#                           'width': 2880}],
#               'place_id': 'ChIJt2Jx8sL4rlQRblO6XKDDEGQ',
#               'plus_code': {'compound_code': 'JQCM+FC Boise, ID, USA',
#                             'global_code': '85M5JQCM+FC'},
#               'rating': 3.8,
#               'reference': 'ChIJt2Jx8sL4rlQRblO6XKDDEGQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1336,
#               'vicinity': '1800 West Fairview Avenue, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.60528, 'lng': -116.2145046},
#                            'viewport': {'northeast': {'lat': 43.60655463029151,
#                                                       'lng': -116.2130472697085},
#                                         'southwest': {'lat': 43.60385666970851,
#                                                       'lng': -116.2157452302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Residence Inn by Marriott Boise Downtown/University',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116249487111930302758">Residence '
#                                                 'Inn by Marriott Boise '
#                                                 'Downtown/University</a>'],
#                           'photo_reference': 'ATtYBwJhLWy3eoh6-XSxhJj88xacjiZc-C2b4cD3pHcdEUl7L9tL0ZWuUBFBIoOLsSvr8lO_3OZiLmO1Y1QKhuji4OzGIJiq9f4U0ihyQs3LJkAMsOz1FxtA45805x9Cz0smNiIIU6Co9qNuz4t3uMyWRBEnNzjhMenx1EayO3KzuZ-OlpXQ',
#                           'width': 2048}],
#               'place_id': 'ChIJsxJPOov4rlQRXV1hYJLrJtE',
#               'plus_code': {'compound_code': 'JQ4P+45 Boise, ID, USA',
#                             'global_code': '85M5JQ4P+45'},
#               'rating': 4.4,
#               'reference': 'ChIJsxJPOov4rlQRXV1hYJLrJtE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 298,
#               'vicinity': '1401 South Lusk Avenue, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.61828420000001,
#                                         'lng': -116.2104662},
#                            'viewport': {'northeast': {'lat': 43.6197211302915,
#                                                       'lng': -116.2094452197085},
#                                         'southwest': {'lat': 43.6170231697085,
#                                                       'lng': -116.2121431802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Modern Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 662,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112918785007667277210">Modern '
#                                                 'Hotel</a>'],
#                           'photo_reference': 'ATtYBwLK3ig-xJhZyuyL099w5WpET4jqtoMag95Df2-Qw6qG-sKs_6x_YUlVMIXHNTuZt9LT3tAqTFmSbkqSHPQvN3OTeX9Qyp58hKnZpJyAyt_aGcwYDNX9SnAfU31HbOw5n-RHEbjopBVdYEuwB7EQTF3SqcRu11Cfk9CEwKbRAkGZ2Qo1',
#                           'width': 894}],
#               'place_id': 'ChIJ_fZEO-b4rlQRESiN6JvXLD8',
#               'plus_code': {'compound_code': 'JQ9Q+8R Boise, ID, USA',
#                             'global_code': '85M5JQ9Q+8R'},
#               'rating': 4.5,
#               'reference': 'ChIJ_fZEO-b4rlQRESiN6JvXLD8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 620,
#               'vicinity': '1314 West Grove Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.61398049999999,
#                                         'lng': -116.2037791},
#                            'viewport': {'northeast': {'lat': 43.6152466302915,
#                                                       'lng': -116.2022796697085},
#                                         'southwest': {'lat': 43.6125486697085,
#                                                       'lng': -116.2049776302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'The Grove Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 553,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116907876961523237058">The '
#                                                 'Grove Hotel</a>'],
#                           'photo_reference': 'ATtYBwJgGFGu2_ik2iySxtFu34IH4FMFnEWmnOAy5fZtqQK0iZP-iYf7XfTx-_15iafS2bbZbGA72ACdsvdca9Q5GMb2E4eReu517g1V_oaofz-IhGlNJi-QWO6kzDholIni3l8zuha1iE_udcak8fZ-6Dcs6DKRe6-ZghGUNuFobfdsfdNc',
#                           'width': 983}],
#               'place_id': 'ChIJJ4IrIeX4rlQRqU4eEpEWDNE',
#               'plus_code': {'compound_code': 'JQ7W+HF Boise, ID, USA',
#                             'global_code': '85M5JQ7W+HF'},
#               'rating': 4.4,
#               'reference': 'ChIJJ4IrIeX4rlQRqU4eEpEWDNE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1853,
#               'vicinity': '245 South Capitol Boulevard, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6140237, 'lng': -116.20365},
#                            'viewport': {'northeast': {'lat': 43.6152092802915,
#                                                       'lng': -116.2025636697085},
#                                         'southwest': {'lat': 43.6125113197085,
#                                                       'lng': -116.2052616302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Western Masonry Insulation Llc',
#               'place_id': 'ChIJqwf45IOJrlQRFyTMYart4RQ',
#               'plus_code': {'compound_code': 'JQ7W+JG Boise, ID, USA',
#                             'global_code': '85M5JQ7W+JG'},
#               'reference': 'ChIJqwf45IOJrlQRFyTMYart4RQ',
#               'scope': 'GOOGLE',
#               'types': ['general_contractor',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '155 S Pronghorn Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6163889, 'lng': -116.2030556},
#                            'viewport': {'northeast': {'lat': 43.6178294802915,
#                                                       'lng': -116.2017953197085},
#                                         'southwest': {'lat': 43.61513151970851,
#                                                       'lng': -116.2044932802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'name': 'Fork',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106310461181903907703">Prerit '
#                                                 'Mishra</a>'],
#                           'photo_reference': 'ATtYBwI48ds9CY5MbmDdbOAxBaFjG86BiqFgP_Of-juIdblJTOSdrW6m6Rk4frk79EHI-okHkZhkg5oKNlqKhW0bZ2nvCJ43sjnhvLmT2AtUjHJDLSZq0hIYjGjP03ppum-9JFfhmePxwS5_EEwdbmMUZY2892TxXVawwVz3Di0m3KcigzxJ',
#                           'width': 4032}],
#               'place_id': 'ChIJhZiKh-T4rlQRwIe2dmc7VAI',
#               'plus_code': {'compound_code': 'JQ8W+HQ Boise, ID, USA',
#                             'global_code': '85M5JQ8W+HQ'},
#               'price_level': 2,
#               'rating': 4.5,
#               'reference': 'ChIJhZiKh-T4rlQRwIe2dmc7VAI',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2378,
#               'vicinity': '199 North 8th Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6140498, 'lng': -116.2021779},
#                            'viewport': {'northeast': {'lat': 43.6153156302915,
#                                                       'lng': -116.2008898197085},
#                                         'southwest': {'lat': 43.6126176697085,
#                                                       'lng': -116.2035877802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'name': 'Bardenay Restaurant & Distillery - Boise',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2846,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104346401522110827947">bill '
#                                                 'carroll</a>'],
#                           'photo_reference': 'ATtYBwIgi4Fj18tTfsdDFrwFNbThixCGXuxW5DHubjjDqSuKi1vgEOnisi3H8Hxp3JWwMjiBGNrltmd-XS-FN80phne2CmSpB-pL2LconAafEBwMN8JdgI9KHzaZqkNhErmu8iOvsr6yqQ2W2Z-L5R8f3z5h8dzB_Kr31POSJKkslr96IhV3',
#                           'width': 3795}],
#               'place_id': 'ChIJN8rsMvv4rlQRk0ZIq_0dQxI',
#               'plus_code': {'compound_code': 'JQ7X+J4 Boise, ID, USA',
#                             'global_code': '85M5JQ7X+J4'},
#               'price_level': 2,
#               'rating': 4.6,
#               'reference': 'ChIJN8rsMvv4rlQRk0ZIq_0dQxI',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1738,
#               'vicinity': '610 West Grove Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.62090849999999,
#                                         'lng': -116.2227421},
#                            'viewport': {'northeast': {'lat': 43.6221536802915,
#                                                       'lng': -116.2213740197085},
#                                         'southwest': {'lat': 43.6194557197085,
#                                                       'lng': -116.2240719802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Budget Inn',
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102294394358559432305">Meghan '
#                                                 'DePonceau</a>'],
#                           'photo_reference': 'ATtYBwIszCaD-8NVnhZ2ocC30_TGPteMJQM9ZpMC-77OjhrmVSqT2tVjJutu_7P9A7aKkGB0sFpyaFnPkLxuPSYj_VVFJvw7rpPaZ-DwHqMR4ZQ2J43I5ghKi1CzDlAc_0osR0uHzcZ-6_Tmcaef1h-rILrGge0FBrdWybybn-Lak4nzxvP-',
#                           'width': 3024}],
#               'place_id': 'ChIJJ-jNhMH4rlQRG8RsN3xFH3k',
#               'plus_code': {'compound_code': 'JQCG+9W Boise, ID, USA',
#                             'global_code': '85M5JQCG+9W'},
#               'rating': 2.3,
#               'reference': 'ChIJJ-jNhMH4rlQRG8RsN3xFH3k',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 369,
#               'vicinity': '2600 West Fairview Avenue, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.62075610000001,
#                                         'lng': -116.2131845},
#                            'viewport': {'northeast': {'lat': 43.62205558029149,
#                                                       'lng': -116.2119597197085},
#                                         'southwest': {'lat': 43.6193576197085,
#                                                       'lng': -116.2146576802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Cabana Inn',
#               'photos': [{'height': 3648,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105137229087567967125">Cabana '
#                                                 'Inn</a>'],
#                           'photo_reference': 'ATtYBwJ1IKjEETCxTXSGOvIcIQqRwINFSfk5BRIRWv7nyvBxI8yDnjodx3KFQFNTJJ9XhDHq-CWMsWiH_phTkFp35tyMTexCjbK8ax0c0fw7F6rMSzFxw2v-xQwgGRlbMmNXUZxPzxY6S4wL98toiGP96NCcrAWU8upTCZBZUSlY9AW1l36L',
#                           'width': 5472}],
#               'place_id': 'ChIJeSAR_Of4rlQRkBRtiGD3jTQ',
#               'plus_code': {'compound_code': 'JQCP+8P Boise, ID, USA',
#                             'global_code': '85M5JQCP+8P'},
#               'rating': 3.1,
#               'reference': 'ChIJeSAR_Of4rlQRkBRtiGD3jTQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 418,
#               'vicinity': '1600 Main Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6211781, 'lng': -116.2025293},
#                            'viewport': {'northeast': {'lat': 43.62240828029149,
#                                                       'lng': -116.2012969197085},
#                                         'southwest': {'lat': 43.6197103197085,
#                                                       'lng': -116.2039948802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Boise High School',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100973267640558806839">Andrew- '
#                                                 'Lynes</a>'],
#                           'photo_reference': 'ATtYBwILvVrpmqwkcRSfarQAyQMMw_J5Ky9UCWoP-iukMvnEXknBWWkPKdx9oohqy11lf9U3XM2PF82tlLdeRV_Agorqt6z1RGfmO2RU2ZpqwdpWtS3WSeMoh7IKxtJIqzujscp7jBtuK4ToYcIy7e0cHSw5Jy3ZNQoyoJDUYsNYgvgoD7o4',
#                           'width': 4032}],
#               'place_id': 'ChIJiROvWOD4rlQRBxezW84etac',
#               'plus_code': {'compound_code': 'JQCW+FX Boise, ID, USA',
#                             'global_code': '85M5JQCW+FX'},
#               'rating': 4.3,
#               'reference': 'ChIJiROvWOD4rlQRBxezW84etac',
#               'scope': 'GOOGLE',
#               'types': ['school',
#                         'secondary_school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 30,
#               'vicinity': '1010 West Washington Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6138951, 'lng': -116.2176486},
#                            'viewport': {'northeast': {'lat': 43.6152923802915,
#                                                       'lng': -116.2163572197085},
#                                         'southwest': {'lat': 43.6125944197085,
#                                                       'lng': -116.2190551802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/post_office-71.png',
#               'name': 'United States Postal Service',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113520397067890569552">Rajkumar '
#                                                 'Manthena</a>'],
#                           'photo_reference': 'ATtYBwJqp6YbliuFtoi2CPKa-bSuQ6IrGVYwypWGMSxDRTav11QtwXFwqn7gSrN4xYdp7mb7O53jLQlYdJMMlGtRlRo2UH8CEz8fuLATeuGvqb9sluoXSbcRHHDzBZA1H-URvS28cWMa92WxPnU8oDHAd0gjomYp_-MRTH5Y7790qG4tQZ1N',
#                           'width': 3024}],
#               'place_id': 'ChIJx50fR-z4rlQRyBMhzlEBLM4',
#               'plus_code': {'compound_code': 'JQ7J+HW Boise, ID, USA',
#                             'global_code': '85M5JQ7J+HW'},
#               'rating': 2.6,
#               'reference': 'ChIJx50fR-z4rlQRyBMhzlEBLM4',
#               'scope': 'GOOGLE',
#               'types': ['post_office',
#                         'finance',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 120,
#               'vicinity': '770 South 13th Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6178216, 'lng': -116.1995185},
#                            'viewport': {'northeast': {'lat': 43.6189047302915,
#                                                       'lng': -116.1984323697085},
#                                         'southwest': {'lat': 43.6162067697085,
#                                                       'lng': -116.2011303302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'name': 'Idaho State Capitol Building',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1984,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112989381729924345409">Idaho '
#                                                 'State Capitol Building</a>'],
#                           'photo_reference': 'ATtYBwLs-Wof_jp_Xl9Yk-LWpCw1zZbbbX-yU_SgFm6yenDDx_PpAOoGx_kJLEOEgqz5Tgpdhjj_1C9I-GtXoOLDAnX24FLT-sMSo2kiwcxKpNo_SwXyQHvYScwceSHGZrHq8rZoICFn4REAwdDMhLX5R959AklU6Biuv1FKA-FAJbdZ6C3B',
#                           'width': 1488}],
#               'place_id': 'ChIJSUtyruP4rlQRWd8MWLOZQp8',
#               'plus_code': {'compound_code': 'JR92+45 Boise, ID, USA',
#                             'global_code': '85M5JR92+45'},
#               'rating': 4.7,
#               'reference': 'ChIJSUtyruP4rlQRWd8MWLOZQp8',
#               'scope': 'GOOGLE',
#               'types': ['local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 158,
#               'vicinity': '700 West Jefferson Street, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6149051, 'lng': -116.2029839},
#                            'viewport': {'northeast': {'lat': 43.6161584302915,
#                                                       'lng': -116.2014513697085},
#                                         'southwest': {'lat': 43.6134604697085,
#                                                       'lng': -116.2041493302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Downtown Boise Association',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2025,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100152842391236571371">Downtown '
#                                                 'Boise Association</a>'],
#                           'photo_reference': 'ATtYBwKqFVAqeoZnnTM8KdcWjPpWcXCfYuSF1Vy62JN9bqmRvvFnMBFsAPddWkkR1U_GrgjO2IJ1hRqdmiIGJgouEeCRXxztbQbtO_yJHtRp1rEJpSButWiSSto5lXZcZLrZhk8Gh_1BVrQA-_Gg33yeYCb7emZ2WCtO_7CZg1e2jnlDcXVD',
#                           'width': 3600}],
#               'place_id': 'ChIJpW1ng-T4rlQRI5k57LPthVs',
#               'plus_code': {'compound_code': 'JQ7W+XR Boise, ID, USA',
#                             'global_code': '85M5JQ7W+XR'},
#               'rating': 4.2,
#               'reference': 'ChIJpW1ng-T4rlQRI5k57LPthVs',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': 'U.S. Bank Plaza, 101 South Capitol Boulevard #206, '
#                           'Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6131926, 'lng': -116.2068729},
#                            'viewport': {'northeast': {'lat': 43.6145181302915,
#                                                       'lng': -116.2054591697085},
#                                         'southwest': {'lat': 43.6118201697085,
#                                                       'lng': -116.2081571302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Knitting Factory Boise',
#               'photos': [{'height': 3526,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107348305870265342736">Knitting '
#                                                 'Factory Boise</a>'],
#                           'photo_reference': 'ATtYBwJF-597H2I8KKvBK1ln-Q-s8YA7ayD1YZAOQYXJ9E-gGxUusjdcsEHHn2iY0o41jQXxb5snwiMMhsth2KalFkxGvli5f62-JMyVC5FAghu2KVVhWM7hmYPmnl91eKLfQG1wU7uWCCTfarGPiduGj5XcJHYVQPIqnFYye7Ge9akQ8xvF',
#                           'width': 5289}],
#               'place_id': 'ChIJ7ZGY_u_4rlQRLQKKXtghuXc',
#               'plus_code': {'compound_code': 'JQ7V+77 Boise, ID, USA',
#                             'global_code': '85M5JQ7V+77'},
#               'rating': 4.3,
#               'reference': 'ChIJ7ZGY_u_4rlQRLQKKXtghuXc',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1284,
#               'vicinity': '416 South 9th Street, Boise'},
#              {'geometry': {'location': {'lat': 43.602661, 'lng': -116.2435466},
#                            'viewport': {'northeast': {'lat': 43.6185066892586,
#                                                       'lng': -116.1938493843277},
#                                         'southwest': {'lat': 43.56630775735019,
#                                                       'lng': -116.2860769276106}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Boise Bench',
#               'place_id': 'ChIJX3MviXv4rlQRz-1t--mZ8hA',
#               'reference': 'ChIJX3MviXv4rlQRz-1t--mZ8hA',
#               'scope': 'GOOGLE',
#               'types': ['neighborhood', 'political'],
#               'vicinity': 'Boise'}],
#  'status': 'OK'}

# %%
for index, row in hotel_df.iterrows():
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    lat=row["Lat"]
    lng=row["Lng"]
    params["location"] = f"{lat},{lng}"
    response = requests.get(base_url, params=params)
    response_json=response.json()
    results = response_json["results"]
    hotel_df.loc[index, "Hotel Name"] = results[0]["name"]

# %%
hotel_df.head(100)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 23             Kavajë  41.1856   19.5569      9.00        46           0
# 24          Beersheba  31.2518   34.7913     18.89        50           0
# 28              Heihe  50.2441  127.4902      0.00        32           0
# 89            Sysert'  56.4953   60.8192      1.00        32           0
# 108          Plumtree -20.4833   27.8167     26.89        29           0
# 122       Chilcuautla  20.3333  -99.2333     15.21        48           0
# 144            Zaranj  30.9667   61.8833     29.00        16           0
# 180  San Buenaventura  27.0833 -101.5333     22.00        12           0
# 254      Tamanghasset  22.7850    5.5228     21.00        17           0
# 257            Shusha  39.7589   46.7492     13.74        49           0
# 290            Klawer -31.7750   18.6256     26.04        45           0
# 297            Durrës  41.3231   19.4414      9.00        46           0
# 311            Xinmin  41.9908  122.8253     10.00        17           0
# 318           Corinth  37.9407   22.9573     13.33        40           0
# 336            Cosalá  24.4125 -106.6908     13.29        28           0
# 351            Gaoual  11.7500  -13.2000     26.22        48           0
# 365        Tlaxcoapan  20.0833  -99.2167     14.01        50           0
# 372            Murzuk  25.9155   13.9184     20.05        21           0
# 413             Silao  20.9333 -101.4333     10.01        39           0
# 447    Monte Escobedo  22.3000 -103.5833      2.06        44           0
# 461       Turkmenabat  39.0733   63.5786     12.00        43           0
# 470            Ashiya  34.7281  135.3026     13.00        41           0
# 473  Törökszentmiklós  47.1833   20.4167      9.00        49           0
# 490           Darling -33.3782   18.3794     25.00        50           0
# 507        Divnogorsk  55.9594   92.3619     -2.00        43           0
# 514          Dingzhou  38.5131  114.9956     14.00        28           0
#
#      Wind speed Country        Date        Hotel Name
# 23         1.03      AL  1615970773            Kavajë
# 24         1.34      IL  1615970773       Be'er Sheva
# 28         5.00      CN  1615970774             Heihe
# 89         7.00      RU  1615970789            Sysert
# 108        3.86      ZW  1615970795          Plumtree
# 122        1.53      MX  1615970798       Chilcuautla
# 144        3.09      AF  1615970803            Zaranj
# 180        4.39      MX  1615970819  San Buenaventura
# 254        7.72      DZ  1615970841       Tamanrasset
# 257        0.24      AZ  1615970841          Xankəndi
# 290        0.32      ZA  1615970848            Klawer
# 297        1.03      AL  1615970850            Durrës
# 311        3.00      CN  1615970853          Shenyang
# 318        6.71      GR  1615970855           Corinth
# 336        1.65      MX  1615970860            Cosalá
# 351        1.71      GN  1615970863            Gaoual
# 365        1.30      MX  1615970866       Atitalaquía
# 372        5.33      LY  1615970868           Murzuq‎
# 413        0.58      MX  1615970878             Silao
# 447        0.34      MX  1615970886    Monte Escobedo
# 461        5.14      TM  1615970890       Turkmenabat
# 470        6.17      JP  1615970661              Kobe
# 473        6.17      HU  1615970893  Törökszentmiklós
# 490        1.54      ZA  1615970897           Darling
# 507        5.00      RU  1615970902        Divnogorsk
# 514        2.00      CN  1615970903           Baoding

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
rating = hotel_df["Humidity"]

# %%
# Plot Heatmap
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add marker layer ontop of heat map


# Display figure
