# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import weather_map_key, google_key
from pprint import pprint

# %% [markdown]
# ## Generate Cities List

# %%
city_df = pd.read_csv("../Resource/worldcities500.csv")
cities_df = city_df[["city"]].copy()
cities_df.head()
# Out:
#       city
# 0    Tokyo
# 1  Jakarta
# 2    Delhi
# 3   Mumbai
# 4   Manila

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create list to to save all the weather information
cities_df["Lat"] = ""
cities_df["Lng"] ="" 
cities_df["Max Temp"] = ""
cities_df["Humidity"] = ""
cities_df["Cloudiness"] = ""
cities_df["Wind_speed"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""

cities_df.head()
# Out:
#       city Lat Lng Max Temp Humidity Cloudiness Wind_speed Country Date
# 0    Tokyo
# 1  Jakarta
# 2    Delhi
# 3   Mumbai
# 4   Manila

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather"

# Setup parameters for the API
params = {"units" : "matric",
         "appid" : weather_map_key,
         "q" : "Melbourne"
}

#Test API and display a city to show the structure of data in API
response = requests.get(url, params = params ).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 28.0836, 'lon': -80.6081},
#  'dt': 1615956900,
#  'id': 4163971,
#  'main': {'feels_like': 292.84,
#           'humidity': 73,
#           'pressure': 1018,
#           'temp': 294.64,
#           'temp_max': 295.37,
#           'temp_min': 293.15},
#  'name': 'Melbourne',
#  'sys': {'country': 'US',
#          'id': 4922,
#          'sunrise': 1615980568,
#          'sunset': 1616023918,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 5.66}}

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather"

# Setup parameters for the API
params = {"units" : "matric",
         "appid" : weather_map_key,}

drop_rows = []

for index, row in cities_df.iterrows():
    city = row["city"]
    params["q"] = city
    
    response = requests.get(url, params = params).json()
    
    
    
    try:
        print("Processing information for city number " + str(index) + " " + city)
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Wind_speed"] = response["wind"]["speed"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
        
    except (KeyError, IndexError):
        print("City not exist, skipping....")
        cities_df.loc[index, "Lat"] = "NaN"
        cities_df.loc[index, "Lng"] = "NaN"
        cities_df.loc[index, "Max Temp"] = "NaN"
        cities_df.loc[index, "Humidity"] = "NaN"
        cities_df.loc[index, "Cloudiness"] = "NaN"
        cities_df.loc[index, "Wind_speed"] = "NaN"
        cities_df.loc[index, "Country"] = "NaN"
        cities_df.loc[index, "Date"] = "NaN"
        cities_df.loc[index, "city"] = "NaN"
        drop_rows.append(index)
    
    print("=====================")
# Out:
# Processing information for city number 0 Tokyo
# =====================
# Processing information for city number 1 Jakarta
# =====================
# Processing information for city number 2 Delhi
# =====================
# Processing information for city number 3 Mumbai
# =====================
# Processing information for city number 4 Manila
# =====================
# Processing information for city number 5 Shanghai
# =====================
# Processing information for city number 6 Seoul
# =====================
# Processing information for city number 7 Mexico City
# =====================
# Processing information for city number 8 Guangzhou
# =====================
# Processing information for city number 9 Beijing
# =====================
# Processing information for city number 10 Cairo
# =====================
# Processing information for city number 11 New York
# =====================
# Processing information for city number 12 Moscow
# =====================
# Processing information for city number 13 Bangkok
# =====================
# Processing information for city number 14 Buenos Aires
# =====================
# Processing information for city number 15 Shenzhen
# =====================
# Processing information for city number 16 Dhaka
# =====================
# Processing information for city number 17 Lagos
# =====================
# Processing information for city number 18 Istanbul
# =====================
# Processing information for city number 19 Karachi
# =====================
# Processing information for city number 20 Bangalore
# =====================
# Processing information for city number 21 Tehran
# =====================
# Processing information for city number 22 Kinshasa
# =====================
# Processing information for city number 23 Ho Chi Minh City
# =====================
# Processing information for city number 24 Los Angeles
# =====================
# Processing information for city number 25 Rio de Janeiro
# =====================
# Processing information for city number 26 Nanyang
# =====================
# Processing information for city number 27 Chennai
# =====================
# Processing information for city number 28 Chengdu
# =====================
# Processing information for city number 29 Lahore
# =====================
# Processing information for city number 30 Paris
# =====================
# Processing information for city number 31 London
# =====================
# Processing information for city number 32 Linyi
# =====================
# Processing information for city number 33 Tianjin
# =====================
# Processing information for city number 34 Shijiazhuang
# =====================
# Processing information for city number 35 Baoding
# =====================
# Processing information for city number 36 Zhoukou
# =====================
# Processing information for city number 37 Lima
# =====================
# Processing information for city number 38 Weifang
# =====================
# Processing information for city number 39 Nagoya
# =====================
# Processing information for city number 40 Wuhan
# =====================
# Processing information for city number 41 Heze
# =====================
# Processing information for city number 42 Ganzhou
# =====================
# Processing information for city number 43 Tongshan
# =====================
# Processing information for city number 44 Chicago
# =====================
# Processing information for city number 45 Handan
# =====================
# Processing information for city number 46 Luanda
# =====================
# Processing information for city number 47 Fuyang
# =====================
# Processing information for city number 48 Kuala Lumpur
# =====================
# Processing information for city number 49 Jining
# =====================
# Processing information for city number 50 Dongguan
# =====================
# Processing information for city number 51 Hanoi
# =====================
# Processing information for city number 52 Pune
# =====================
# Processing information for city number 53 Chongqing
# =====================
# Processing information for city number 54 Changchun
# =====================
# Processing information for city number 55 Zhumadian
# =====================
# Processing information for city number 56 Ningbo
# =====================
# Processing information for city number 57 Onitsha
# =====================
# Processing information for city number 58 Nanjing
# =====================
# Processing information for city number 59 Hefei
# =====================
# Processing information for city number 60 Hong Kong
# =====================
# Processing information for city number 61 Khartoum
# =====================
# Processing information for city number 62 Nantong
# =====================
# Processing information for city number 63 Yancheng
# =====================
# Processing information for city number 64 Foshan
# =====================
# Processing information for city number 65 Nanning
# =====================
# Processing information for city number 66 Hengyang
# =====================
# Processing information for city number 67 Shenyang
# =====================
# Processing information for city number 68 Tangshan
# =====================
# Processing information for city number 69 Shaoyang
# =====================
# Processing information for city number 70 Changsha
# =====================
# Processing information for city number 71 Santiago
# =====================
# Processing information for city number 72 Zhengzhou
# =====================
# Processing information for city number 73 Zhanjiang
# =====================
# Processing information for city number 74 Riyadh
# =====================
# Processing information for city number 75 Cangzhou
# =====================
# Processing information for city number 76 Dar es Salaam
# =====================
# Processing information for city number 77 Maoming
# =====================
# Processing information for city number 78 Huanggang
# =====================
# Processing information for city number 79 Xinyang
# =====================
# Processing information for city number 80 Shangrao
# =====================
# Processing information for city number 81 Luoyang
# =====================
# Processing information for city number 82 Bijie
# =====================
# Processing information for city number 83 Yantai
# =====================
# Processing information for city number 84 Quanzhou
# =====================
# Processing information for city number 85 Hangzhou
# =====================
# Processing information for city number 86 Miami
# =====================
# Processing information for city number 87 Kunming
# =====================
# Processing information for city number 88 Nanchong
# =====================
# Processing information for city number 89 Zunyi
# =====================
# Processing information for city number 90 Yichun
# =====================
# Processing information for city number 91 Taizhou
# =====================
# Processing information for city number 92 Liaocheng
# =====================
# Processing information for city number 93 Qujing
# =====================
# Processing information for city number 94 Xiangyang
# =====================
# Processing information for city number 95 Baghdad
# =====================
# Processing information for city number 96 Qingdao
# =====================
# Processing information for city number 97 Singapore
# =====================
# Processing information for city number 98 Dallas
# =====================
# Processing information for city number 99 Changde
# =====================
# Processing information for city number 100 Dazhou
# =====================
# Processing information for city number 101 Suzhou
# =====================
# Processing information for city number 102 Philadelphia
# =====================
# Processing information for city number 103 Jieyang
# =====================
# Processing information for city number 104 Nairobi
# =====================
# Processing information for city number 105 Nangandao
# City not exist, skipping....
# =====================
# Processing information for city number 106 Ankara
# =====================
# Processing information for city number 107 Yulin
# =====================
# Processing information for city number 108 Dezhou
# =====================
# Processing information for city number 109 Houston
# =====================
# Processing information for city number 110 Atlanta
# =====================
# Processing information for city number 111 Rangoon
# =====================
# Processing information for city number 112 Toronto
# =====================
# Processing information for city number 113 Suihua
# =====================
# Processing information for city number 114 Washington
# =====================
# Processing information for city number 115 Qiqihar
# =====================
# Processing information for city number 116 Jinhua
# =====================
# Processing information for city number 117 Saint Petersburg
# =====================
# Processing information for city number 118 Shantou
# =====================
# Processing information for city number 119 Sydney
# =====================
# Processing information for city number 120 Weinan
# =====================
# Processing information for city number 121 Suqian
# =====================
# Processing information for city number 122 Guadalajara
# =====================
# Processing information for city number 123 Suzhou
# =====================
# Processing information for city number 124 Fuzhou
# =====================
# Processing information for city number 125 Zhaotong
# =====================
# Processing information for city number 126 Pudong
# =====================
# Processing information for city number 127 Yongzhou
# =====================
# Processing information for city number 128 Belo Horizonte
# =====================
# Processing information for city number 129 Zhangzhou
# =====================
# Processing information for city number 130 Bozhou
# =====================
# Processing information for city number 131 Melbourne
# =====================
# Processing information for city number 132 Nanchang
# =====================
# Processing information for city number 133 Xianyang
# =====================
# Processing information for city number 134 Taizhou
# =====================
# Processing information for city number 135 Surabaya
# =====================
# Processing information for city number 136 Abidjan
# =====================
# Processing information for city number 137 Mianyang
# =====================
# Processing information for city number 138 Shaoxing
# =====================
# Processing information for city number 139 Alexandria
# =====================
# Processing information for city number 140 Yuncheng
# =====================
# Processing information for city number 141 Pingdingshan
# =====================
# Processing information for city number 142 Xinpu
# =====================
# Processing information for city number 143 Guilin
# =====================
# Processing information for city number 144 Huaihua
# =====================
# Processing information for city number 145 Jiujiang
# =====================
# Processing information for city number 146 Anqing
# =====================
# Processing information for city number 147 Boston
# =====================
# Processing information for city number 148 Huanglongsi
# =====================
# Processing information for city number 149 Xiaoganzhan
# City not exist, skipping....
# =====================
# Processing information for city number 150 Changzhou
# =====================
# Processing information for city number 151 Barcelona
# =====================
# Processing information for city number 152 Chenzhou
# =====================
# Processing information for city number 153 Wuxi
# =====================
# Processing information for city number 154 Zibo
# =====================
# Processing information for city number 155 Jiaxing
# =====================
# Processing information for city number 156 Dalian
# =====================
# Processing information for city number 157 Harbin
# =====================
# Processing information for city number 158 Yangzhou
# =====================
# Processing information for city number 159 Yibin
# =====================
# Processing information for city number 160 Jiangmen
# =====================
# Processing information for city number 161 Johannesburg
# =====================
# Processing information for city number 162 Meizhou
# =====================
# Processing information for city number 163 Chifeng
# =====================
# Processing information for city number 164 Casablanca
# =====================
# Processing information for city number 165 Guiyang
# =====================
# Processing information for city number 166 Langfang
# =====================
# Processing information for city number 167 Zhangjiakou
# =====================
# Processing information for city number 168 Linfen
# =====================
# Processing information for city number 169 Wenzhou
# =====================
# Processing information for city number 170 Monterrey
# =====================
# Processing information for city number 171 Luzhou
# =====================
# Processing information for city number 172 Jiangguanchi
# =====================
# Processing information for city number 173 Neijiang
# =====================
# Processing information for city number 174 Phoenix
# =====================
# Processing information for city number 175 Yanjiang
# =====================
# Processing information for city number 176 Yiyang
# =====================
# Processing information for city number 177 Zhaoqing
# =====================
# Processing information for city number 178 Hengshui
# =====================
# Processing information for city number 179 Guigang
# =====================
# Processing information for city number 180 Xiaoxita
# =====================
# Processing information for city number 181 Xiamen
# =====================
# Processing information for city number 182 Chuzhou
# =====================
# Processing information for city number 183 Fuzhou
# =====================
# Processing information for city number 184 Amman
# =====================
# Processing information for city number 185 Jeddah
# =====================
# Processing information for city number 186 Sialkot City
# City not exist, skipping....
# =====================
# Processing information for city number 187 Huizhou
# =====================
# Processing information for city number 188 Qingyuan
# =====================
# Processing information for city number 189 Zhuzhou
# =====================
# Processing information for city number 190 Wuhu
# =====================
# Processing information for city number 191 Hechi
# =====================
# Processing information for city number 192 Seattle
# =====================
# Processing information for city number 193 Loudi
# =====================
# Processing information for city number 194 Binzhou
# =====================
# Processing information for city number 195 Liuzhou
# =====================
# Processing information for city number 196 Yokohama
# =====================
# Processing information for city number 197 Baojishi
# City not exist, skipping....
# =====================
# Processing information for city number 198 Hanzhong
# =====================
# Processing information for city number 199 Kabul
# =====================
# Processing information for city number 200 Zaozhuang
# =====================
# Processing information for city number 201 Berlin
# =====================
# Processing information for city number 202 Anshan
# =====================
# Processing information for city number 203 Deyang
# =====================
# Processing information for city number 204 Lanzhou
# =====================
# Processing information for city number 205 Chengde
# =====================
# Processing information for city number 206 San Francisco
# =====================
# Processing information for city number 207 Puyang
# =====================
# Processing information for city number 208 Suining
# =====================
# Processing information for city number 209 Jiaozuo
# =====================
# Processing information for city number 210 Bengbu
# =====================
# Processing information for city number 211 Detroit
# =====================
# Processing information for city number 212 Baicheng
# =====================
# Processing information for city number 213 Busan
# =====================
# Processing information for city number 214 Algiers
# =====================
# Processing information for city number 215 Qincheng
# =====================
# Processing information for city number 216 Taiyuan
# =====================
# Processing information for city number 217 Lucknow
# =====================
# Processing information for city number 218 Chaoyang
# =====================
# Processing information for city number 219 Hechi
# =====================
# Processing information for city number 220 Leshan
# =====================
# Processing information for city number 221 Yulinshi
# =====================
# Processing information for city number 222 Siping
# =====================
# Processing information for city number 223 Madrid
# =====================
# Processing information for city number 224 Jinan
# =====================
# Processing information for city number 225 Shiyan
# =====================
# Processing information for city number 226 Changzhi
# =====================
# Processing information for city number 227 San Diego
# =====================
# Processing information for city number 228 Faisalabad
# =====================
# Processing information for city number 229 Santa Cruz
# =====================
# Processing information for city number 230 Bazhou
# =====================
# Processing information for city number 231 Zhongshan
# =====================
# Processing information for city number 232 Zhenjiang
# =====================
# Processing information for city number 233 Tongliao
# =====================
# Processing information for city number 234 Heyuan
# =====================
# Processing information for city number 235 Tongren
# =====================
# Processing information for city number 236 Qinzhou
# =====================
# Processing information for city number 237 Jaipur
# =====================
# Processing information for city number 238 Xinzhou
# =====================
# Processing information for city number 239 Addis Ababa
# =====================
# Processing information for city number 240 Giza
# =====================
# Processing information for city number 241 Meishan
# =====================
# Processing information for city number 242 Mashhad
# =====================
# Processing information for city number 243 Jinzhou
# =====================
# Processing information for city number 244 Tieling
# =====================
# Processing information for city number 245 Shaoguan
# =====================
# Processing information for city number 246 Shanwei
# =====================
# Processing information for city number 247 Minneapolis
# =====================
# Processing information for city number 248 Kyiv
# =====================
# Processing information for city number 249 Sanaa
# =====================
# Processing information for city number 250 Quezon City
# =====================
# Processing information for city number 251 Dingxi
# =====================
# Processing information for city number 252 Salvador
# =====================
# Processing information for city number 253 Incheon
# =====================
# Processing information for city number 254 Bursa
# =====================
# Processing information for city number 255 Ningde
# =====================
# Processing information for city number 256 Tampa
# =====================
# Processing information for city number 257 Daqing
# =====================
# Processing information for city number 258 Birmingham
# =====================
# Processing information for city number 259 Putian
# =====================
# Processing information for city number 260 Huzhou
# =====================
# Processing information for city number 261 Wuzhou
# =====================
# Processing information for city number 262 Denver
# =====================
# Processing information for city number 263 Rome
# =====================
# Processing information for city number 264 La Paz
# =====================
# Processing information for city number 265 Pyongyang
# =====================
# Processing information for city number 266 Kano
# =====================
# Processing information for city number 267 Taichung
# =====================
# Processing information for city number 268 Omdurman
# =====================
# Processing information for city number 269 Zigong
# =====================
# Processing information for city number 270 Qinhuangdao
# =====================
# Processing information for city number 271 Mudanjiang
# =====================
# Processing information for city number 272 Huludao
# =====================
# Processing information for city number 273 Kaohsiung
# =====================
# Processing information for city number 274 Xiangtan
# =====================
# Processing information for city number 275 Guayaquil
# =====================
# Processing information for city number 276 Rizhao
# =====================
# Processing information for city number 277 Manchester
# =====================
# Processing information for city number 278 Cawnpore
# City not exist, skipping....
# =====================
# Processing information for city number 279 Baotou
# =====================
# Processing information for city number 280 Taipei
# =====================
# Processing information for city number 281 Nanping
# =====================
# Processing information for city number 282 Longyan
# =====================
# Processing information for city number 283 Ibadan
# =====================
# Processing information for city number 284 Hohhot
# =====================
# Processing information for city number 285 Chaozhou
# =====================
# Processing information for city number 286 Antananarivo
# =====================
# Processing information for city number 287 Longba
# =====================
# Processing information for city number 288 Weihai
# =====================
# Processing information for city number 289 Chattogram
# City not exist, skipping....
# =====================
# Processing information for city number 290 Santo Domingo
# =====================
# Processing information for city number 291 Xuanzhou
# =====================
# Processing information for city number 292 Sanming
# =====================
# Processing information for city number 293 Brooklyn
# =====================
# Processing information for city number 294 Brisbane
# =====================
# Processing information for city number 295 Baoshan
# =====================
# Processing information for city number 296 Dubai
# =====================
# Processing information for city number 297 Luohe
# =====================
# Processing information for city number 298 Qinbaling
# City not exist, skipping....
# =====================
# Processing information for city number 299 Guangyuan
# =====================
# Processing information for city number 300 Cali
# =====================
# Processing information for city number 301 Daegu
# =====================
# Processing information for city number 302 Fortaleza
# =====================
# Processing information for city number 303 Guatemala City
# =====================
# Processing information for city number 304 Douala
# =====================
# Processing information for city number 305 Jilin
# =====================
# Processing information for city number 306 Lianshan
# =====================
# Processing information for city number 307 Lincang
# =====================
# Processing information for city number 308 Antalya
# =====================
# Processing information for city number 309 Tashkent
# =====================
# Processing information for city number 310 Huangshi
# =====================
# Processing information for city number 311 Bandung
# =====================
# Processing information for city number 312 Dandong
# =====================
# Processing information for city number 313 Huainan
# =====================
# Processing information for city number 314 Shangzhou
# =====================
# Processing information for city number 315 Bekasi
# =====================
# Processing information for city number 316 Tijuana
# =====================
# Processing information for city number 317 Jiamusi
# =====================
# Processing information for city number 318 Yangjiang
# =====================
# Processing information for city number 319 Accra
# =====================
# Processing information for city number 320 Yuxi
# =====================
# Processing information for city number 321 Fushun
# =====================
# Processing information for city number 322 Anshun
# =====================
# Processing information for city number 323 Vancouver
# =====================
# Processing information for city number 324 Tangerang
# =====================
# Processing information for city number 325 Konya
# =====================
# Processing information for city number 326 Queens
# =====================
# Processing information for city number 327 Yingkou
# =====================
# Processing information for city number 328 Adana
# =====================
# Processing information for city number 329 Medan
# =====================
# Processing information for city number 330 Sanmenxia
# =====================
# Processing information for city number 331 Indore
# =====================
# Processing information for city number 332 Pingliang
# =====================
# Processing information for city number 333 Quzhou
# =====================
# Processing information for city number 334 Baku
# =====================
# Processing information for city number 335 Gaoping
# =====================
# Processing information for city number 336 Huaibei
# =====================
# Processing information for city number 337 Xining
# =====================
# Processing information for city number 338 Havana
# =====================
# Processing information for city number 339 Phnom Penh
# =====================
# Processing information for city number 340 Fukuoka
# =====================
# Processing information for city number 341 Mogadishu
# =====================
# Processing information for city number 342 Jincheng
# =====================
# Processing information for city number 343 Lishui
# =====================
# Processing information for city number 344 Qingyang
# =====================
# Processing information for city number 345 Riverside
# =====================
# Processing information for city number 346 Baltimore
# =====================
# Processing information for city number 347 Haiphong
# =====================
# Processing information for city number 348 Las Vegas
# =====================
# Processing information for city number 349 Laibin
# =====================
# Processing information for city number 350 Rawalpindi
# =====================
# Processing information for city number 351 Kumasi
# =====================
# Processing information for city number 352 Portland
# =====================
# Processing information for city number 353 Vadodara
# =====================
# Processing information for city number 354 Perth
# =====================
# Processing information for city number 355 Puning
# =====================
# Processing information for city number 356 San Antonio
# =====================
# Processing information for city number 357 Haikou
# =====================
# Processing information for city number 358 Gaziantep
# =====================
# Processing information for city number 359 Minsk
# =====================
# Processing information for city number 360 St. Louis
# =====================
# Processing information for city number 361 Bamako
# =====================
# Processing information for city number 362 Quito
# =====================
# Processing information for city number 363 Pingxiang
# =====================
# Processing information for city number 364 Chongzuo
# =====================
# Processing information for city number 365 Kananga
# =====================
# Processing information for city number 366 Peshawar
# =====================
# Processing information for city number 367 Sapporo
# =====================
# Processing information for city number 368 Jixi
# =====================
# Processing information for city number 369 Caracas
# =====================
# Processing information for city number 370 Fuxin
# =====================
# Processing information for city number 371 Leeds
# =====================
# Processing information for city number 372 Sacramento
# =====================
# Processing information for city number 373 Blantyre
# =====================
# Processing information for city number 374 Tainan
# =====================
# Processing information for city number 375 Bucharest
# =====================
# Processing information for city number 376 Wuwei
# =====================
# Processing information for city number 377 BhopÄl
# City not exist, skipping....
# =====================
# Processing information for city number 378 Curitiba
# =====================
# Processing information for city number 379 Xiping
# =====================
# Processing information for city number 380 Saidu Sharif
# =====================
# Processing information for city number 381 Vienna
# =====================
# Processing information for city number 382 Aleppo
# =====================
# Processing information for city number 383 Hamburg
# =====================
# Processing information for city number 384 Meru
# =====================
# Processing information for city number 385 Brazzaville
# =====================
# Processing information for city number 386 Orlando
# =====================
# Processing information for city number 387 Mersin
# =====================
# Processing information for city number 388 Almaty
# =====================
# Processing information for city number 389 Barranquilla
# =====================
# Processing information for city number 390 Manaus
# =====================
# Processing information for city number 391 Liaoyang
# =====================
# Processing information for city number 392 Baiyin
# =====================
# Processing information for city number 393 San Jose
# =====================
# Processing information for city number 394 Warsaw
# =====================
# Processing information for city number 395 Shengli
# =====================
# Processing information for city number 396 Lubumbashi
# =====================
# Processing information for city number 397 Damascus
# =====================
# Processing information for city number 398 Shuyangzha
# City not exist, skipping....
# =====================
# Processing information for city number 399 Shangqiu
# =====================
# Processing information for city number 400 Budapest
# =====================
# Processing information for city number 401 Heihe
# =====================
# Processing information for city number 402 Lusaka
# =====================
# Processing information for city number 403 Chinchvad
# =====================
# Processing information for city number 404 Shuozhou
# =====================
# Processing information for city number 405 Cleveland
# =====================
# Processing information for city number 406 Pittsburgh
# =====================
# Processing information for city number 407 Mecca
# =====================
# Processing information for city number 408 Patna
# =====================
# Processing information for city number 409 Mosul
# =====================
# Processing information for city number 410 Austin
# =====================
# Processing information for city number 411 Sanzhou
# =====================
# Processing information for city number 412 Conakry
# =====================
# Processing information for city number 413 Kampala
# =====================
# Processing information for city number 414 Ecatepec
# =====================
# Processing information for city number 415 Cincinnati
# =====================
# Processing information for city number 416 Makassar
# =====================
# Processing information for city number 417 Yushan
# =====================
# Processing information for city number 418 LudhiÄna
# City not exist, skipping....
# =====================
# Processing information for city number 419 Newcastle
# =====================
# Processing information for city number 420 Depok
# =====================
# Processing information for city number 421 Zhongli
# =====================
# Processing information for city number 422 Kansas City
# =====================
# Processing information for city number 423 Rabat
# =====================
# Processing information for city number 424 Ouagadougou
# =====================
# Processing information for city number 425 Davao
# =====================
# Processing information for city number 426 Manhattan
# =====================
# Processing information for city number 427 Semarang
# =====================
# Processing information for city number 428 Yinchuan
# =====================
# Processing information for city number 429 Multan
# =====================
# Processing information for city number 430 Caloocan City
# =====================
# Processing information for city number 431 Harare
# =====================
# Processing information for city number 432 Novosibirsk
# =====================
# Processing information for city number 433 Chengtangcun
# =====================
# Processing information for city number 434 Karaj
# =====================
# Processing information for city number 435 Indianapolis
# =====================
# Processing information for city number 436 Jingdezhen
# =====================
# Processing information for city number 437 Puebla
# =====================
# Processing information for city number 438 KalyÄn
# City not exist, skipping....
# =====================
# Processing information for city number 439 Madurai
# =====================
# Processing information for city number 440 Gujranwala
# =====================
# Processing information for city number 441 Benxi
# =====================
# Processing information for city number 442 Jamshedpur
# =====================
# Processing information for city number 443 Zhuhai
# =====================
# Processing information for city number 444 Recife
# =====================
# Processing information for city number 445 Columbus
# =====================
# Processing information for city number 446 Santiago
# =====================
# Processing information for city number 447 Maracaibo
# =====================
# Processing information for city number 448 Beihai
# =====================
# Processing information for city number 449 Shuangyashan
# =====================
# Processing information for city number 450 Charlotte
# =====================
# Processing information for city number 451 Yucheng
# =====================
# Processing information for city number 452 Changshu
# =====================
# Processing information for city number 453 Ximeicun
# =====================
# Processing information for city number 454 Jianguang
# =====================
# Processing information for city number 455 Gwangju
# =====================
# Processing information for city number 456 Xushan
# =====================
# Processing information for city number 457 Guiping
# =====================
# Processing information for city number 458 Porto Alegre
# =====================
# Processing information for city number 459 Zhangjiajie
# =====================
# Processing information for city number 460 Valencia
# =====================
# Processing information for city number 461 Virginia Beach
# =====================
# Processing information for city number 462 Daejeon
# =====================
# Processing information for city number 463 Munich
# =====================
# Processing information for city number 464 Yekaterinburg
# =====================
# Processing information for city number 465 Auckland
# =====================
# Processing information for city number 466 Yunfu
# =====================
# Processing information for city number 467 Huangshan
# =====================
# Processing information for city number 468 Huazhou
# =====================
# Processing information for city number 469 Pizhou
# =====================
# Processing information for city number 470 Palembang
# =====================
# Processing information for city number 471 Kharkiv
# =====================
# Processing information for city number 472 Kawanakajima
# City not exist, skipping....
# =====================
# Processing information for city number 473 Lianjiang
# =====================
# Processing information for city number 474 Chizhou
# =====================
# Processing information for city number 475 Leizhou
# =====================
# Processing information for city number 476 Guyuan
# =====================
# Processing information for city number 477 Birstall
# =====================
# Processing information for city number 478 Muscat
# =====================
# Processing information for city number 479 Hebi
# =====================
# Processing information for city number 480 Jingling
# =====================
# Processing information for city number 481 Bronx
# =====================
# Processing information for city number 482 The Hague
# =====================
# Processing information for city number 483 Owerri
# =====================
# Processing information for city number 484 Sharjah
# =====================
# Processing information for city number 485 Ulaanbaatar
# =====================
# Processing information for city number 486 Kayseri
# =====================
# Processing information for city number 487 Yueqing
# =====================
# Processing information for city number 488 Belgrade
# =====================
# Processing information for city number 489 Pingdu
# =====================
# Processing information for city number 490 Yutan
# =====================
# Processing information for city number 491 Wenling
# =====================
# Processing information for city number 492 Islamabad
# =====================
# Processing information for city number 493 Milwaukee
# =====================
# Processing information for city number 494 Milan
# =====================
# Processing information for city number 495 Sofia
# =====================
# Processing information for city number 496 Adelaide
# =====================
# Processing information for city number 497 Samsun
# =====================
# Processing information for city number 498 Khulna
# =====================
# Processing information for city number 499 Guarulhos
# =====================
# Processing information for city number 500 Prague
# =====================
# Processing information for city number 501 Montevideo
# =====================
# Processing information for city number 502 Mbuji-Mayi
# =====================
# Processing information for city number 503 Fuqing
# =====================
# Processing information for city number 504 Xintai
# =====================
# Processing information for city number 505 Doha
# =====================
# Processing information for city number 506 Saitama
# =====================
# Processing information for city number 507 Hiroshima
# =====================
# Processing information for city number 508 Meerut
# =====================

# %%
print(len(cities_df))
# Out:
# 509

# %%
cities_df.dropna()
# Out:
#           city      Lat      Lng Max Temp Humidity Cloudiness Wind_speed  \
# 0        Tokyo  35.6895  139.692   292.15       26         75       4.12
# 1      Jakarta  -6.2146  106.845   305.15       51         40       1.54
# 2        Delhi  28.6667  77.2167   298.15       61         40       2.06
# 3       Mumbai  19.0144  72.8479   306.15       31         40       2.06
# 4       Manila  14.6042  120.982   307.04       55         20       2.06
# ..         ...      ...      ...      ...      ...        ...        ...
# 504     Xintai  35.9006  117.752   289.39       20          0       2.79
# 505       Doha  25.2867  51.5333   298.71       94          5       2.57
# 506    Saitama  35.9081  139.657   293.71       29         75       4.12
# 507  Hiroshima  34.3963  132.459   290.15       67         75       2.57
# 508     Meerut  28.9833     77.7   305.54       15          0       4.51
#
#     Country        Date
# 0        JP  1615957144
# 1        ID  1615957007
# 2        IN  1615957140
# 3        IN  1615956983
# 4        PH  1615956927
# ..      ...         ...
# 504      CN  1615957293
# 505      QA  1615957227
# 506      JP  1615957291
# 507      JP  1615957034
# 508      IN  1615957208
#
# [509 rows x 9 columns]

# %%
#Save the dataframe into a CSV file
#cities_df.to_csv("../Output/cities_original.csv", index = False, header = True)

# %%
len(cities_df)
# Out:
# 509

# %%
#Save the dataframe into a CSV file
#cities_df.to_csv("../Output/cities.csv", index = False, header = True)

# %%
Lat =[]
Lng=[]
Max_Temp=[]
Humidity=[]
Cloudiness=[]
Wind_speed=[]
Country=[]
Date=[]
City=[]

counter = 0
for x in cities_df["Lat"]: 
    if x == "NaN":
        print("oh no")
    else:
        Lat = cities_df["Lat"]
        Lng=cities_df["Lng"]
        Max_Temp=cities_df["Max Temp"]
        Humidity=cities_df["Humidity"]
        Cloudiness=cities_df["Cloudiness"]
        Wind_speed=cities_df["Wind_speed"]
        Country=cities_df["Country"]
        Date=cities_df["Date"]
        City=cities_df["city"]
        counter +=1

print(counter)

print(len(Lng))

# %%
new_df = pd.DataFrame({"City": City,
                       "Lat" : Lat,
                       "Lng" : Lng,
                       "Max Temp" : Max_Temp,
                       "Humidity" : Humidity,
                       "Cloudiness" : Cloudiness,
                       "Wind speed" : Wind_speed,
                       "Country" : Country,
                       "Date" : Date})

# %%
new_df.to_csv("../Output/cities.csv", index = False, header = True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity = cities_df["Humidity"]
print(humidity)

# %%
#  Get the indices of cities that have humidity over 100%.
for x in humidity:
    if x != "" and x > 100:
        print("oh no, humidity is more than 100%! That's hot!")

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
